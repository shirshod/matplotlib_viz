# %% [markdown]
# ## Matplotlib: An Introduction
#
# The topics and code covered in this notebook are sourced from W3 Schools (with little tweaks here and there) and from my own research.
#
# The comments and explanations are either my own or from the website. Refer to the website for more examples and details. Read more [here](https://www.w3schools.com/python/matplotlib_intro.asp).

# %% [markdown]
# ### What is Matplotlib?
#
# Matplotlib is an open source, low-level graph plotting library in Python that serves as a visualization utility.
# It is mostly written in Python, with a few segments in C, Objective-C and Javascript for platform compatibility.
#
# Matplotlib was created by John D. Hunter. Read more [here](https://github.com/matplotlib/matplotlib).

# %% [markdown]
# ### Importing libraries

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Plotting — basics

# %% [markdown]
# #### Plotting a line with two coordinates

# %%
### defines all x-coordinates
xpoints = np.array([0, 6])

### defines all y-coordinates
ypoints = np.array([0, 250])

### plots line (line-plotting is the default when just two points are given)
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #### Plotting just the two points with coordinates

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

### plots points 
plt.plot(xpoints, ypoints, "o")
plt.show()

# %% [markdown]
# Note: The "o" is shorthand for "ring"

# %% [markdown]
# #### Plotting a line chart with multiple points

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

### plots line 
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #### Plotting points when only one coordinate is given

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, "o")
plt.show()

# %% [markdown]
# Note: When only one coordinate is given, the other defaults to 0, 1, 2 and so on.

# %% [markdown]
# ### Markers

# %% [markdown]
# #### Plotting a line and marking each point with a circle

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = "o")
plt.show()

# %% [markdown]
# #### Plotting a line and marking each point with an asterisk

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = "*")
plt.show()

# %% [markdown]
# Note: More shorthands for markers can be found [here](https://www.w3schools.com/python/matplotlib_markers.asp).

# %% [markdown]
# #### Plotting a dotted red line

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, "o:r")
plt.show()

# %% [markdown]
# Note: More shorthands for line and color can be found [here](https://www.w3schools.com/python/matplotlib_markers.asp).

# %% [markdown]
# #### Manipulating marker size

# %%
ypoints = np.array([3, 8, 1, 10])

### sets marker size at 20
plt.plot(ypoints, marker = "o", ms = 20)
plt.show()

# %% [markdown]
# #### Manipulating marker color

# %%
ypoints = np.array([3, 8, 1, 10])

### sets marker edge-color as red
plt.plot(ypoints, marker = "o", ms = 20, mec = "r")
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

### sets marker face-color as red
plt.plot(ypoints, marker = "o", ms = 20, mfc = "r")
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

### sets both marker edge and face-color as red
plt.plot(ypoints, marker = "o", ms = 20, mec = "r", mfc = "r")
plt.show()

# %% [markdown]
# Note: Instead of shorthands, hexidecimal color values can also be used. Refer to the color schema [here](https://www.w3schools.com/colors/colors_hexadecimal.asp).

# %% [markdown]
# ### Manipulating line styles

# %% [markdown]
# #### Plotting a dotted line

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = "dotted")
plt.show()

# %% [markdown]
# #### Plotting a dashed line

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = "dashed")
plt.show()

# %% [markdown]
# Note: "linestyle" can also be written as "ls"

# %% [markdown]
# #### Manipulating line colors

# %%
ypoints = np.array([3, 8, 1, 10])

### sets line-color to red
plt.plot(ypoints, color = "r")
plt.show()

# %% [markdown]
# #### Manipulating line size

# %%
ypoints = np.array([3, 8, 1, 10])

### sets line-width to 20.5
plt.plot(ypoints, linewidth = "20.5")
plt.show()

# %% [markdown]
# ### Drawing multiple lines

# %% [markdown]
# #### Drawing two lines from only one coordinate type

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# #### Drawing two lines when both coordinates are given for each set

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# #### Plotting just the points from the coordinates

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, "o", x2, y2, "o")
plt.show()

# %% [markdown]
# ### Defining labels

# %% [markdown]
# #### Axis labels

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

### defines label for x-axis
plt.xlabel("Average Pulse")
### defines label for y-axis
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# #### Chart title

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

### defines chart title
plt.title("Sports Watch Data")

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# #### Title positioning

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

### aligns label to the left
plt.title("Sports Watch Data", loc = "left")

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Adding grid lines

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# #### Setting which grid-lines to display

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

### displays grid on only x-axis
plt.grid(axis = "x")

plt.show()

# %% [markdown]
# #### Manipulating properties of the grid lines

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = "green", ls = "--", linewidth = 0.5)

plt.show()

# %% [markdown]
# ### Subplots

# %% [markdown]
# #### Plotting two charts in same figure horizontally

# %%
### plot 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

### subplot display has one row (1), two columns (2) and is the first plot (1)
plt.subplot(1, 2, 1)
plt.plot(x,y)

### plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

### subplot display has one row (1), two columns (2) and is the second plot (2)
plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# #### Plotting two charts in same figure vertically

# %%
### plot 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

### subplot display has two rows (2), one column (1) and is the first plot (1)
plt.subplot(2, 1, 1)
plt.plot(x,y)

### plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

### subplot display has two rows (2), one column (2) and is the second plot (2)
plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %% [markdown]
# #### Plotting six charts in figure with two rows and three columns

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# Note: The figures are plotted row-wise. Row 1 has first three figures and row 2 last three.

# %% [markdown]
# #### Adding titles to each plot

# %%
### plot 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

### adds title to plot 1
plt.title("SALES")

### plot 2
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

### adds title to plot 2
plt.title("INCOME")

plt.show()

# %% [markdown]
# #### Adding title to whole figure

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

### adds "super-title"
plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# ### Scatter plots

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])

plt.scatter(x, y)
plt.xlabel("Age of car")
plt.ylabel("Speed of car")
plt.show()

# %% [markdown]
# #### Two plots on same figure

# %%
### day one, the age and speed of 13 cars
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
plt.scatter(x, y)

### day two, the age and speed of 15 cars
x = np.array([2, 2, 8, 1, 15, 8, 12, 9, 7, 3, 11, 4, 7, 14, 12])
y = np.array([100, 105, 84, 105, 90, 99, 90, 95, 94, 100, 79, 112, 91, 80, 85])
plt.scatter(x, y)
plt.xlabel("Age of car")
plt.ylabel("Speed of car")

plt.show()

# %% [markdown]
# Note: From the chart we can conclude that the newer the car, the faster it goes

# %% [markdown]
# #### Manipulating colors

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
plt.scatter(x, y, color = "hotpink")

x = np.array([2, 2, 8, 1, 15, 8, 12, 9, 7, 3, 11, 4, 7, 14, 12])
y = np.array([100, 105, 84, 105, 90, 99, 90, 95, 94, 100, 79, 112, 91, 80, 85])
plt.scatter(x, y, color = "#88c999")

plt.xlabel("Age of car")
plt.ylabel("Speed of car")

plt.show()

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c = colors)

plt.xlabel("Age of car")
plt.ylabel("Speed of car")

plt.show()

# %% [markdown]
# #### Using colorbars

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c = colors, cmap = "viridis")

### shows colorbar beside chart
plt.colorbar()

plt.show()

# %% [markdown]
# Note: For more colorbars, refer to the schema [here](https://www.w3schools.com/python/matplotlib_scatter.asp).

# %% [markdown]
# #### Manipulating sizes

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
sizes = np.array([20, 50, 100, 200, 500, 1000, 60, 90, 10, 300, 600, 800, 75])

plt.scatter(x, y, s = sizes)

plt.show()

# %% [markdown]
# #### Adjusting transparency

# %%
x = np.array([5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6])
y = np.array([99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86])
sizes = np.array([20, 50, 100, 200, 500, 1000, 60, 90, 10, 300, 600, 800, 75])

plt.scatter(x, y, s = sizes, alpha = 0.5)

plt.show()

# %% [markdown]
# #### Combining multiple style properties

# %%
### creates random elements with 100 values for x and y coordinates, colors and sizes
x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))
colors = np.random.randint(100, size = (100))
sizes = 10 * np.random.randint(100, size = (100))

plt.scatter(x, y, c = colors, s = sizes, alpha = 0.5, cmap = "nipy_spectral")

plt.colorbar()

plt.show()

# %% [markdown]
# ### Barcharts

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = ["APPLES", "BANANAS"]
y = [400, 350]

plt.bar(x, y)
plt.show()

# %% [markdown]
# #### Horizontal bar charts

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y)
plt.show()

# %% [markdown]
# #### Manipulating bar colors

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, color = "#4CAF50")
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, color = "hotpink")
plt.show()

# %% [markdown]
# #### Manipulating bar width

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x, y, width = 0.25)
plt.show()

# %% [markdown]
# #### Manipulating bar height

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y, height = 0.2)
plt.show()

# %% [markdown]
# ### Histograms

# %% [markdown]
# Note: A histogram is a graph showing frequency distributions. It is a graph showing the number of observations within each given interval.

# %%
### generates a random normal distribution with 250 values, concentrated around 170 with standard deviation as 10
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [156.54163885 174.30002926 168.52295528 170.12399761 176.14482583
#  187.50374291 171.40428    158.2880156  171.54639757 184.84903972
#  166.53833575 170.2916125  162.26125295 168.04008822 167.91907151
#  198.26848837 166.46217739 165.93914477 174.99131309 170.21030531
#  164.12241361 169.05331904 174.6347293  159.39050279 178.44992576
#  180.74627154 168.91584203 175.54715924 175.43558173 174.26834126
#  155.18433146 162.1296543  184.6021139  185.27442045 157.97942864
#  160.54566086 169.48928318 167.01043472 180.12759835 181.30216534
#  173.97562661 150.93562962 179.9252195  188.53846631 165.87079727
#  160.04726834 182.22354477 184.07361022 175.84719582 143.10155224
#  157.00766522 171.5860917  184.84564815 171.86375179 170.28096746
#  163.39960744 173.15353559 152.56856825 173.90682527 172.26007224
#  179.71597667 173.30526211 187.60952926 167.65037872 195.53020618
#  175.86547056 160.18879599 163.85414676 158.54781538 156.70563487
# ...

# %%
### plots a histogram from the distribution
plt.hist(x)
plt.show()

# %% [markdown]
# ### Pie charts

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %% [markdown]
# Note: The pie chart draws one piece (called a wedge) for each value in the array (in this case [35, 25, 25, 15]). By default the plotting of the first wedge starts from the x-axis and moves counterclockwise.
# The size of each wedge is determined by comparing the value with all the other values, by using the formula x/sum(x).

# %% [markdown]
# #### Adding labels

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# Note: The default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter. The startangle parameter is defined with an angle in degrees, default angle is 0.

# %% [markdown]
# #### Manipulating start angles

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

### changes start angle to 90 degrees (first wedge starts at 90)
plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# #### Explode wedge

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# #### Adding shadows

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %% [markdown]
# #### Manipulating colors

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# #### Adding legend

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

### labels adds legend
plt.pie(y, labels = mylabels)
### adds legend title
plt.legend(title = "Four Fruits:")
plt.show()
